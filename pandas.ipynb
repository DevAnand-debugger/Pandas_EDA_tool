# %% [markdown]
# <a href="https://colab.research.google.com/github/DevAnand-debugger/Pandas_EDA_tool/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Name=Dev Anand
#
# ###PRN=25070123039
#
# ###Batch=A2
#
# ####Experiment-9
#
# ###Study of pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40])
s#Pandas give a minimum of 2 dimensional array
#Also if print(s) than it only shows the output
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create DataFrame
data = {
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
#Find the Structure of the Data Frame
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check all dtypes of DataFrame
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access Individual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
#Access Specific Row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
#Add a New Column
df["Grade"]= ["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
df.loc[0,"Marks"]= 88
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
df.drop("Grade",axis=1,inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Perform Basic Statistical Analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
mode1=df["Marks"].mode()
mode1
# Out:
# 0    78
# 1    88
# 2    90
# Name: Marks, dtype: int64

# %%
median1=df["Marks"].median()
median1
# Out:
# 88.0

# %%
min1=df["Marks"].min()
max1=df["Marks"].max()
print(min1,max1)
# Out:
# 78 90

# %%
#Apply Condition (Filtering)
#Display students having marks greater than 80
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
